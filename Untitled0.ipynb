# %% [markdown]
# <a href="https://colab.research.google.com/github/muskanchawla/muskan/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastai==0.7.0
# Out:
# Requirement already satisfied: fastai==0.7.0 in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: isoweek in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.28.1)
# Requirement already satisfied: pandas-summary in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.0.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.13)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (5.5.0)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.1.7)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (7.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.7.5)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (17.0.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.4.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.1.0)
# Requirement already satisfied: feather-format in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.0)
# Requirement already satisfied: MarkupSafe in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.1.1)
# Requirement already satisfied: torch<0.4 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.3.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.6.1)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.10.1)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.6.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.9.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.0.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.5.20)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2018.9)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.2.2.post3)
# Requirement already satisfied: bcolz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.2.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.3)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.16.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.2.1)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.0.3)
# Requirement already satisfied: jedi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.13.3)
# Requirement already satisfied: sklearn-pandas in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (1.8.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.5.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2019.3.9)
# Requirement already satisfied: widgetsnbextension in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (3.4.2)
# Requirement already satisfied: plotnine in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.5.1)
# Requirement already satisfied: cycler in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.10.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.5.3)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (4.3.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.4.0)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (0.8.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from fastai==0.7.0) (2.6.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai==0.7.0) (0.46)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext->fastai==0.7.0) (2.21.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (1.0.16)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (4.7.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->fastai==0.7.0) (41.0.1)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (4.4.4)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (6.0.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.2.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from jupyter->fastai==0.7.0) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bleach->fastai==0.7.0) (1.12.0)
# Requirement already satisfied: pyarrow>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from feather-format->fastai==0.7.0) (0.13.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel->fastai==0.7.0) (5.2.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai==0.7.0) (1.1.0)
# Requirement already satisfied: parso>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from jedi->fastai==0.7.0) (0.4.0)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-pandas->fastai==0.7.0) (0.20.3)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.1)
# Requirement already satisfied: statsmodels>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.9.0)
# Requirement already satisfied: descartes>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (1.1.0)
# Requirement already satisfied: mizani>=0.5.2 in /usr/local/lib/python3.6/dist-packages (from plotnine->fastai==0.7.0) (0.5.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext->fastai==0.7.0) (1.24.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->fastai==0.7.0) (4.4.0)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->fastai==0.7.0) (0.8.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.6.0)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->jupyter->fastai==0.7.0) (1.4.2)
# Requirement already satisfied: palettable in /usr/local/lib/python3.6/dist-packages (from mizani>=0.5.2->plotnine->fastai==0.7.0) (3.1.1)

# %%
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# Out:
#      |████████████████████████████████| 26.6MB 4.2MB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-94ce375e95cb> in <module>()
#       1 from fastai.imports import *
# ----> 2 from fastai.transforms import *
#       3 from fastai.conv_learner import *
#       4 from fastai.model import *
#       5 from fastai.dataset import *
#
# /usr/local/lib/python3.6/dist-packages/fastai/transforms.py in <module>()
#       1 from .imports import *
# ----> 2 from .layer_optimizer import *
#       3 from enum import IntEnum
#       4
#       5 def scale_min(im, targ, interpolation=cv2.INTER_AREA):
#
# /usr/local/lib/python3.6/dist-packages/fastai/layer_optimizer.py in <module>()
#       1 from .imports import *
# ----> 2 from .torch_imports import *
#       3 from .core import *
#       4
#       5 def opt_params(parm, lr, wd):
#
# /usr/local/lib/python3.6/dist-packages/fastai/torch_imports.py in <module>()
#       1 import os
# ----> 2 import torch, torchvision, torchtext
#       3 from torch import nn, cuda, backends, FloatTensor, LongTensor, optim
#       4 import torch.nn.functional as F
#       5 from torch.autograd import Variable
#
# /usr/local/lib/python3.6/dist-packages/torchtext/__init__.py in <module>()
# ----> 1 from . import data
#       2 from . import datasets
#       3 from . import utils
#       4 from . import vocab
#       5
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/__init__.py in <module>()
#       2 from .dataset import Dataset, TabularDataset
#       3 from .example import Example
# ----> 4 from .field import RawField, Field, ReversibleField, SubwordField, NestedField, LabelField
#       5 from .iterator import (batch, BucketIterator, Iterator, BPTTIterator,
#       6                        pool)
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py in <module>()
#      59
#      60
# ---> 61 class Field(RawField):
#      62     """Defines a datatype together with instructions for converting to Tensor.
#      63
#
# /usr/local/lib/python3.6/dist-packages/torchtext/data/field.py in Field()
#     116     # numeric type.
#     117     dtypes = {
# --> 118         torch.float32: float,
#     119         torch.float: float,
#     120         torch.float64: float,
#
# AttributeError: module 'torch' has no attribute 'float32'

# %%
# !pip install "torchtext==0.2.3"
# Out:
# Collecting torchtext==0.2.3
#   Downloading https://files.pythonhosted.org/packages/78/90/474d5944d43001a6e72b9aaed5c3e4f77516fbef2317002da2096fd8b5ea/torchtext-0.2.3.tar.gz (42kB)
#      |████████████████████████████████| 51kB 2.0MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (3.0.4)
# Building wheels for collected packages: torchtext
#   Building wheel for torchtext (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/42/a6/f4/b267328bde6bb680094a0c173e8e5627ccc99543abded97204
# Successfully built torchtext
# Installing collected packages: torchtext
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# Successfully installed torchtext-0.2.3

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
torch.cuda.is_available()
torch.backends.cudnn.enabled
# Out:
# True

# %%
! git clone https://github.com/muskanchawla/muskan.git
# Out:
# fatal: destination path 'muskan' already exists and is not an empty directory.

# %%
! ls
# Out:
# muskan	sample_data

# %%
! ls
# Out:
# muskan	sample_data

# %%
df_raw = pd.read_csv('Train.csv', low_memory=False, 
                     parse_dates=["saledate"])

# %%
import pandas as pd

# %%
df_raw
# Out:
#         SalesID  SalePrice  ...  Differential_Type  Steering_Controls
# 0       1139246      66000  ...           Standard       Conventional
# 1       1139248      57000  ...           Standard       Conventional
# 2       1139249      10000  ...                NaN                NaN
# 3       1139251      38500  ...                NaN                NaN
# 4       1139253      11000  ...                NaN                NaN
# 5       1139255      26500  ...                NaN                NaN
# 6       1139256      21000  ...                NaN                NaN
# 7       1139261      27000  ...                NaN                NaN
# 8       1139272      21500  ...                NaN                NaN
# 9       1139275      65000  ...           Standard       Conventional
# 10      1139278      24000  ...                NaN                NaN
# 11      1139282      22500  ...                NaN                NaN
# 12      1139283      36000  ...                NaN                NaN
# 13      1139284      30500  ...                NaN                NaN
# 14      1139290      28000  ...                NaN                NaN
# 15      1139291      19000  ...                NaN                NaN
# 16      1139292      13500  ...                NaN                NaN
# 17      1139299       9500  ...                NaN                NaN
# 18      1139301      12500  ...                NaN                NaN
# 19      1139304      11500  ...                NaN                NaN
# 20      1139311      41000  ...                NaN                NaN
# 21      1139333      34500  ...                NaN                NaN
# 22      1139344      26000  ...                NaN                NaN
# 23      1139346      73000  ...           Standard       Conventional
# 24      1139348      33000  ...                NaN                NaN
# 25      1139351      12500  ...                NaN                NaN
# 26      1139354      15500  ...                NaN                NaN
# 27      1139356      53000  ...                NaN                NaN
# 28      1139357      46000  ...                NaN                NaN
# 29      1139358      89000  ...                NaN                NaN
# ...         ...        ...  ...                ...                ...
# 250361  1764841      29500  ...           Standard       Conventional
# 250362  1764842      37000  ...           Standard       Conventional
# 250363  1764843      41000  ...           Standard       Conventional
# 250364  1764844      57500  ...           Standard       Conventional
# 250365  1764845      40000  ...           Standard       Conventional
# 250366  1764847      34000  ...           Standard       Conventional
# 250367  1764851      36000  ...           Standard       Conventional
# 250368  1764852      35000  ...           Standard       Conventional
# 250369  1764853      29000  ...           Standard       Conventional
# 250370  1764856      39000  ...           Standard       Conventional
# 250371  1764858      42000  ...           Standard       Conventional
# 250372  1764859      39000  ...           Standard       Conventional
# 250373  1764860      38000  ...           Standard       Conventional
# 250374  1764871      23500  ...           Standard       Conventional
# 250375  1764874      29000  ...           Standard       Conventional
# 250376  1764875      27500  ...           Standard       Conventional
# 250377  1764876      29000  ...           Standard       Conventional
# 250378  1764877      26000  ...           Standard       Conventional
# 250379  1764878      33000  ...           Standard       Conventional
# 250380  1764879      39000  ...           Standard       Conventional
# 250381  1764880      72500  ...                NaN                NaN
# 250382  1764881      56000  ...                NaN                NaN
# 250383  1764882      17500  ...                NaN                NaN
# 250384  1764884      22000  ...                NaN                NaN
# 250385  1764885      22000  ...                NaN                NaN
# 250386  1764886      28000  ...                NaN                NaN
# 250387  1764887      69000  ...                NaN                NaN
# 250388  1764888      56500  ...                NaN                NaN
# 250389  1764889      12500  ...                NaN                NaN
# 250390  1764891      75000  ...                NaN                NaN
#
# [250391 rows x 53 columns]

# %%
import numpy as np

# %%
df_raw.SalePrice = np.log(df_raw.SalePrice)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.imports import *
from fastai.structured import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %%
load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
matplotlib inline
# Out:
#   File "<ipython-input-27-f18922216956>", line 1
#     matplotlib inline
#                     ^
# SyntaxError: invalid syntax

# %%
m = RandomForestRegressor(n_jobs=-1)

# %%
m.fit(df_raw.drop('SalePrice', axis=1), df_raw.SalePrice)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-d830c74391b1> in <module>()
# ----> 1 m.fit(df_raw.drop('SalePrice', axis=1), df_raw.SalePrice)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Low'

# %%
def add_datepart(df, fldname, drop=True):
    fld = df[fldname]
    if not np.issubdtype(fld.dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, 
                                     infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    for n in ('Year', 'Month', 'Week', 'Day', 'Dayofweek', 
            'Dayofyear', 'Is_month_end', 'Is_month_start', 
            'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 
            'Is_year_start'):
        df[targ_pre+n] = getattr(fld.dt,n.lower())
    df[targ_pre+'Elapsed'] = fld.astype(np.int64) // 10**9
    if drop: df.drop(fldname, axis=1, inplace=True)

# %%
fld = df_raw.saledate
fld.dt.year
# Out:
# 0         2006
# 1         2004
# 2         2004
# 3         2011
# 4         2009
# 5         2008
# 6         2004
# 7         2005
# 8         2009
# 9         2007
# 10        2008
# 11        2006
# 12        2005
# 13        2006
# 14        2006
# 15        2006
# 16        2007
# 17        2010
# 18        2006
# 19        2005
# 20        2006
# 21        2006
# 22        2007
# 23        2006
# 24        2004
# 25        2006
# 26        2006
# 27        2007
# 28        2007
# 29        2006
#           ...
# 250361    2004
# 250362    2000
# 250363    2000
# 250364    2005
# 250365    2003
# 250366    2001
# 250367    2003
# 250368    2004
# 250369    2002
# 250370    2001
# 250371    2001
# 250372    2001
# 250373    2003
# 250374    2007
# 250375    2005
# 250376    2007
# 250377    2005
# 250378    2007
# 250379    2006
# 250380    2005
# 250381    1993
# 250382    1996
# 250383    2008
# 250384    2006
# 250385    2006
# 250386    1997
# 250387    1992
# 250388    1995
# 250389    2001
# 250390    2006
# Name: saledate, Length: 250391, dtype: int64

# %%
add_datepart(df_raw, 'saledate')
df_raw.saleYear.head()
# Out:
# 0    2006
# 1    2004
# 2    2004
# 3    2011
# 4    2009
# Name: saleYear, dtype: int64

# %%
train_cats(df_raw)
df_raw.UsageBand.cat.categories
Index(['High', 'Low', 'Medium'], dtype='object)
# Out:
#   File "<ipython-input-33-816dc6584152>", line 3
#     Index(['High', 'Low', 'Medium'], dtype='object)
#                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
df_raw.UsageBand.cat.categories
# Out:
# Index(['High', 'Low', 'Medium'], dtype='object')

# %%
df_raw.UsageBand.cat.set_categories(['High', 'Medium', 'Low'],
    ordered=True, inplace=True)

# %%
train_cats(df_raw)

# %%
df_raw.UsageBand.cat.set_categories(['High', 'Medium', 'Low'],
    ordered=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-cdf201405589> in <module>()
# ----> 1 df_raw.UsageBand.cat.set_categories(['High', 'Medium', 'Low'],
#       2     ordered=True, inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
#     173         # http://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/categorical.py in __init__(self, data)
#    2489
#    2490     def __init__(self, data):
# -> 2491         self._validate(data)
#    2492         self._parent = data.values
#    2493         self._index = data.index
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/categorical.py in _validate(data)
#    2498     def _validate(data):
#    2499         if not is_categorical_dtype(data.dtype):
# -> 2500             raise AttributeError("Can only use .cat accessor with a "
#    2501                                  "'category' dtype")
#    2502
#
# AttributeError: Can only use .cat accessor with a 'category' dtype

# %%
? train_cats

# %%
def split_vals(a,n): return a[:n].copy(), a[:n].copy

# %%
? split_vals

# %%
n_valid = 12000  # same as Kaggle's test set size
n_trn = len(df_raw)-n_valid
raw_train, raw_valid = split_vals(df_raw, n_trn)
X_train, X_valid = split_vals(df_raw, n_trn)
y_train, y_valid = split_vals(y, n_trn)
X_train.shape, y_train.shape, X_valid.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-91760e77a3a4> in <module>()
#       3 raw_train, raw_valid = split_vals(df_raw, n_trn)
#       4 X_train, X_valid = split_vals(df_raw, n_trn)
# ----> 5 y_train, y_valid = split_vals(y, n_trn)
#       6 X_train.shape, y_train.shape, X_valid.shape
#
# NameError: name 'y' is not defined

# %%
m = RandomForestRegressor(n_jobs=-1)

# %%
m.fit(df_raw.drop('SalePrice', axis=1), df_raw.SalePrice)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-d830c74391b1> in <module>()
# ----> 1 m.fit(df_raw.drop('SalePrice', axis=1), df_raw.SalePrice)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Low'

# %%
def add_datepart(df, fldname, drop=True):
    fld = df[fldname]
    if not np.issubdtype(fld.dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, 
                                     infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    for n in ('Year', 'Month', 'Week', 'Day', 'Dayofweek', 
            'Dayofyear', 'Is_month_end', 'Is_month_start', 
            'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 
            'Is_year_start'):
        df[targ_pre+n] = getattr(fld.dt,n.lower())
    df[targ_pre+'Elapsed'] = fld.astype(np.int64) // 10**9
    if drop: df.drop(fldname, axis=1, inplace=True)

# %%
fld = df_raw

# %%
df_raw
# Out:
#         SalesID  SalePrice  ...  saleIs_year_start  saleElapsed
# 0       1139246   2.406712  ...              False   1163635200
# 1       1139248   2.393413  ...              False   1080259200
# 2       1139249   2.220327  ...              False   1077753600
# 3       1139251   2.356923  ...              False   1305763200
# 4       1139253   2.230622  ...              False   1248307200
# 5       1139255   2.320906  ...              False   1229558400
# 6       1139256   2.297801  ...              False   1093478400
# 7       1139261   2.322740  ...              False   1132185600
# 8       1139272   2.300163  ...              False   1251331200
# 9       1139275   2.405335  ...              False   1186617600
# 10      1139278   2.311129  ...              False   1219276800
# 11      1139282   2.304710  ...              False   1156377600
# 12      1139283   2.350544  ...              False   1129766400
# 13      1139284   2.334615  ...              False   1138233600
# 14      1139290   2.326298  ...              False   1136246400
# 15      1139291   2.287694  ...              False   1163635200
# 16      1139292   2.252391  ...              False   1181779200
# 17      1139299   2.214742  ...              False   1264636800
# 18      1139301   2.244265  ...              False   1141862400
# 19      1139304   2.235387  ...              False   1132185600
# 20      1139311   2.362864  ...              False   1147910400
# 21      1139333   2.346479  ...              False   1161216000
# 22      1139344   2.319034  ...              False   1193270400
# 23      1139346   2.415754  ...              False   1161216000
# 24      1139348   2.342216  ...              False   1085011200
# 25      1139351   2.244265  ...              False   1141862400
# 26      1139354   2.266812  ...              False   1141862400
# 27      1139356   2.386747  ...              False   1172102400
# 28      1139357   2.373640  ...              False   1186617600
# 29      1139358   2.433297  ...              False   1149120000
# ...         ...        ...  ...                ...          ...
# 250361  1764841   2.331381  ...              False   1104364800
# 250362  1764842   2.353152  ...              False    968889600
# 250363  1764843   2.362864  ...              False    952992000
# 250364  1764844   2.394210  ...              False   1108425600
# 250365  1764845   2.360536  ...              False   1044835200
# 250366  1764847   2.345081  ...              False    993168000
# 250367  1764851   2.350544  ...              False   1046217600
# 250368  1764852   2.347855  ...              False   1088208000
# 250369  1764853   2.329719  ...              False   1017360000
# 250370  1764856   2.358144  ...              False    991872000
# 250371  1764858   2.365130  ...              False   1008115200
# 250372  1764859   2.358144  ...              False    993686400
# 250373  1764860   2.355684  ...              False   1056499200
# 250374  1764871   2.309040  ...              False   1171584000
# 250375  1764874   2.329719  ...              False   1107820800
# 250376  1764875   2.324537  ...              False   1171238400
# 250377  1764876   2.329719  ...              False   1107734400
# 250378  1764877   2.319034  ...              False   1171238400
# 250379  1764878   2.342216  ...              False   1158192000
# 250380  1764879   2.358144  ...              False   1118275200
# 250381  1764880   2.415140  ...              False    753408000
# 250382  1764881   2.391796  ...              False    835747200
# 250383  1764882   2.279312  ...              False   1202428800
# 250384  1764884   2.302465  ...              False   1139529600
# 250385  1764885   2.302465  ...              False   1139097600
# 250386  1764886   2.326298  ...              False    881280000
# 250387  1764887   2.410709  ...              False    720403200
# 250388  1764888   2.392608  ...              False    802137600
# 250389  1764889   2.244265  ...              False    985132800
# 250390  1764891   2.418165  ...              False   1141776000
#
# [250391 rows x 65 columns]

# %%
? RandomForestRegressor

# %%
df, y, nas = proc_df(df_raw, 'SalePrice')

# %%
df.head()
# Out:
#    SalesID  MachineID  ...  saleElapsed  MachineHoursCurrentMeter_na
# 0  1139246     999089  ...   1163635200                        False
# 1  1139248     117657  ...   1080259200                        False
# 2  1139249     434808  ...   1077753600                        False
# 3  1139251    1026470  ...   1305763200                        False
# 4  1139253    1057373  ...   1248307200                        False
#
# [5 rows x 65 columns]

# %%
m.fit(df_raw, df_raw.SalePrice)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-eea410f6fefd> in <module>()
# ----> 1 m.fit(df_raw, df_raw.SalePrice)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Low'

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(df, y)
m.score(df,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9807092870730665

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()
n_valid = 12000  # same as Kaggle's test set size
n_trn = len(df)-n_valid
raw_train, raw_valid = split_vals(df_raw, n_trn)
X_train, X_valid = split_vals(df, n_trn)
y_train, y_valid = split_vals(y, n_trn)
X_train.shape, y_train.shape, X_valid.shape
# Out:
# ((238391, 65), (238391,), (12000, 65))

# %%
df_raw.SalePrice = np.log(df_raw.SalePrice)

# %%
m.fit(df_raw.drop('SalePrice', axis=1), df_raw.SalePrice)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-d830c74391b1> in <module>()
# ----> 1 m.fit(df_raw.drop('SalePrice', axis=1), df_raw.SalePrice)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     248
#     249         # Validate or convert input data
# --> 250         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     251         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     252         if sample_weight is not None:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Low'

# %%
def rmse(x,y): return math.sqrt(((x-y)**2).mean())

# %%
? proc_df

# %%
df_trn, y_trn, nas = proc_df(df_raw, 'SalePrice', subset=30000, 
                     na_dict=nas)
X_train, _ = split_vals(df_trn, 20000)
y_train, _ = split_vals(y_trn, 20000)

# %%
m = RandomForestRegressor(n_estimators=1, max_depth=3,
                          bootstrap=False, n_jobs=-1)

# %%
m.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print_score(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-9d52ab0813bd> in <module>()
#       1
# ----> 2 print_score(m)
#
# NameError: name 'print_score' is not defined

# %%
m
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print_score(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-a7253ecd009b> in <module>()
# ----> 1 print_score(m)
#
# NameError: name 'print_score' is not defined

# %%
m = RandomForestRegressor(n_estimators=1, max_depth=3,
                          bootstrap=False, n_jobs=-1)
m.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, criterion='mse', max_depth=3,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
m = RandomForestRegressor( n_jobs=-1)

# %%
print_score(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-a7253ecd009b> in <module>()
# ----> 1 print_score(m)
#
# NameError: name 'print_score' is not defined

# %%
def print_score(m):
    res = [rmse(m.predict(X_train), y_train), rmse(m.predict(X_valid), y_valid),
                m.score(X_train, y_train), m.score(X_valid, y_valid)]
    if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
m = RandomForestRegressor(n_jobs=-1)
m.fit(X_train, y_train)
print_score(m)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.010299415324396039, 0.051599903161329744, 0.975097413917942, 0.28716177983498425]

# %%
? m.score

# %%
m = RandomForestRegressor(n_estimators=1, max_depth=3,
                          bootstrap=False, n_jobs=-1)
m.fit(X_train, y_train)
print_score(m)
